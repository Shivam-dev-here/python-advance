# %% [markdown]
# # Memory Management
# Includes topics helps in memory (allocation/deallocation) efficiency++
#
# ---
# #### Topics Covered
# - Reference Counting
# - Automatic garbage Collections
#
# ---
